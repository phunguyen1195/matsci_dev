# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-7dd3504c366f> in <module>
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
ls data/*.csv
# Out:
# data/dimethyl_sulfoxide_pkin.csv  data/dimethyl_sulfoxide_solare.csv

# %%
df = pd.read_csv("data/dimethyl_sulfoxide_solare.csv")

# %%
df2=pd.read_csv("data/dimethyl_sulfoxide_pkin.csv")

# %%
set(df2["Name"]) - set(df["Name"])
# Out:
# {'CCDC_200727.lis',
#  'CCDC_1574950.lis',
#  'CCDC_270380.lis',
#  'CCDC_939572.lis',
#  'CCDC_911289.lis',
#  'CCDC_648753.lis',
#  'CCDC_654217.lis',
#  'CCDC_877494.lis',
#  'CCDC_854332.lis',
#  'CCDC_796040.lis',
#  'CCDC_1514234.lis',
#  'CCDC_745201.lis',
#  'CCDC_1554364.lis',
#  'CCDC_1028502.lis',
#  'CCDC_684895.lis',
#  'CCDC_158067.lis',
#  'CCDC_838386.lis',
#  'CCDC_932472.lis',
#  'CCDC_975629.lis',
#  'CCDC_1871790.lis',
#  'CCDC_923112.lis',
#  'CCDC_741452.lis',
#  'CCDC_273146.lis',
#  'CCDC_900744.lis',
#  'CCDC_1570744.lis',
#  'CCDC_106656.lis',
#  'CCDC_268694.lis',
#  'CCDC_643525.lis',
#  'CCDC_283652.lis',
#  'CCDC_1051663.lis',
#  'CCDC_1413396.lis',
#  'CCDC_1420328.lis',
#  'CCDC_1015559.lis',
#  'CCDC_283374.lis',
#  'CCDC_1551687.lis',
#  'CCDC_140947.lis',
#  'CCDC_666678.lis',
#  'CCDC_1424345.lis',
#  'CCDC_1870545.lis',
#  'CCDC_637505.lis',
#  'CCDC_175490.lis',
#  'CCDC_1010554.lis',
#  'CCDC_628619.lis',
#  'CCDC_1850344.lis',
# ...

# %%
df3 = df2[df2["packing_index"] > 80]

# %%
df["so"]
# Out:
#       Unnamed: 0              Name  packing_index
# 80            80   CCDC_980259.lis           80.2
# 86            86   CCDC_963501.lis           80.6
# 447          447   CCDC_163699.lis           81.4
# 578          578  CCDC_1142838.lis           82.1
# 686          686   CCDC_782161.lis           81.6
# 1113        1113   CCDC_705417.lis           80.8
# 1145        1145   CCDC_957156.lis           83.3
# 1191        1191   CCDC_689073.lis           89.2
# 1292        1292   CCDC_932102.lis           80.2
# 1358        1358   CCDC_901691.lis           82.6
# 1675        1675   CCDC_240869.lis           89.5
# 2043        2043   CCDC_898463.lis           86.0
# 2148        2148  CCDC_1563998.lis           80.5
# 2332        2332   CCDC_606353.lis           84.5
# 2387        2387  CCDC_1012086.lis           81.2
# 2439        2439   CCDC_835359.lis           81.8
# 2682        2682   CCDC_824483.lis           81.0
# 3019        3019  CCDC_1566730.lis           81.2
# ...
