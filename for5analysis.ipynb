# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/home/phunguyen/Documents/for5analysis_pkin_den_form.csv")

# %%
df.drop([4], axis=0, inplace=True)

# %%
x = df["packing_index"].to_list()
y = df["Density"].to_list()
z = ['C15 H27 F9 K3 N3 O9 S3', 'C12 H21 F6 Li2 N3 O6 S2', 'C10 H18 F6 N2 O6 Rb2 S2', 'C10 H18 Cs2 F6 N2 O6 S2']
fig, ax = plt.subplots()
ax.scatter(x, y)
plt.grid()
plt.title("for5analysis: packing index vs. density")
plt.xlabel("packing index")
plt.ylabel("density")
plt.savefig('/home/phunguyen/Documents/for5analysis.png')
