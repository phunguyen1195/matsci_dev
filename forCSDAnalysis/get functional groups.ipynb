# %%
import pandas as pd
import io

# %%
d = "/home/phunguyen/Documents/CDSana_2/output_vdw.csv"

# %%
df = pd.read_csv(d)

# %%
print (df["detail observed"][0])
# Out:
#     coordination_count                     label  probability
# 0                    0  "N1 of T3NH0_cyclic (a)"     1.000000
# 3                    0  "N3 of T3NH0_cyclic (a)"     1.000000
# 5                    0  "N4 of T3NH0_cyclic (a)"     1.000000
# 6                    0  "N5 of T3NH0_cyclic (a)"     1.000000
# 7                    0  "N6 of T3NH0_cyclic (a)"     1.000000
# 8                    0  "N7 of T3NH0_cyclic (a)"     1.000000
# 9                    0  "N8 of T3NH0_cyclic (a)"     1.000000
# 1                    0  "N2 of T3NH0_cyclic (a)"     1.000000
# 25                   0        "O23 of T2OH0 (a)"     0.999801
# 26                   0        "O24 of T2OH0 (a)"     0.999801
# 17                   0        "O18 of T2OH0 (a)"     0.999794
# 15                   0        "O17 of T2OH0 (a)"     0.999792
# 23                   0        "O21 of T2OH0 (a)"     0.999791
# 24                   0        "O22 of T2OH0 (a)"     0.999790
# ...

# %%
s = df["detail observed"][0]

# %%
io.BytesIO(s)

# %%
df_detail = pd.read_table(io.BytesIO(s), delim_whitespace=True)
# Out:
# /home/phunguyen/anaconda3/envs/matsci_py27/lib/python2.7/site-packages/ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   """Entry point for launching an IPython kernel.

# %%
df_detail[['atom', 'of','func_group', 'a']] = df_detail.label.str.split(expand=True)

# %%
df_detail.drop(columns=['of','a'])
# Out:
#     coordination_count                   label  probability atom    func_group
# 0                    0  N1 of T3NH0_cyclic (a)     1.000000   N1  T3NH0_cyclic
# 3                    0  N3 of T3NH0_cyclic (a)     1.000000   N3  T3NH0_cyclic
# 5                    0  N4 of T3NH0_cyclic (a)     1.000000   N4  T3NH0_cyclic
# 6                    0  N5 of T3NH0_cyclic (a)     1.000000   N5  T3NH0_cyclic
# 7                    0  N6 of T3NH0_cyclic (a)     1.000000   N6  T3NH0_cyclic
# 8                    0  N7 of T3NH0_cyclic (a)     1.000000   N7  T3NH0_cyclic
# 9                    0  N8 of T3NH0_cyclic (a)     1.000000   N8  T3NH0_cyclic
# 1                    0  N2 of T3NH0_cyclic (a)     1.000000   N2  T3NH0_cyclic
# 25                   0        O23 of T2OH0 (a)     0.999801  O23         T2OH0
# 26                   0        O24 of T2OH0 (a)     0.999801  O24         T2OH0
# 17                   0        O18 of T2OH0 (a)     0.999794  O18         T2OH0
# ...
